# %%
my_elements = {
  "instrument": "EUR_USD",
  "granularity": "S5",
  "candles": [
    {
      "complete": "true",
      "volume": 3,
      "time": "2023-05-05T20:57:00.000000000Z",
      "mid": {
        "o": "1.10186",
        "h": "1.10188",
        "l": "1.10186",
        "c": "1.10188"
      }
    },
    {
      "complete": "true",
      "volume": 5,
      "time": "2023-05-05T20:57:05.000000000Z",
      "mid": {
        "o": "1.10189",
        "h": "1.10190",
        "l": "1.10189",
        "c": "1.10189"
      }
    },
    {
      "complete": "true",
      "volume": 1,
      "time": "2023-05-05T20:57:10.000000000Z",
      "mid": {
        "o": "1.10188",
        "h": "1.10188",
        "l": "1.10188",
        "c": "1.10188"
      }
    },
    {
      "complete": "true",
      "volume": 1,
      "time": "2023-05-05T20:57:40.000000000Z",
      "mid": {
        "o": "1.10186",
        "h": "1.10186",
        "l": "1.10186",
        "c": "1.10186"
      }
    },
    {
      "complete": "true",
      "volume": 2,
      "time": "2023-05-05T20:57:50.000000000Z",
      "mid": {
        "o": "1.10186",
        "h": "1.10188",
        "l": "1.10186",
        "c": "1.10188"
      }
    },
    {
      "complete": "true",
      "volume": 2,
      "time": "2023-05-05T20:57:55.000000000Z",
      "mid": {
        "o": "1.10186",
        "h": "1.10188",
        "l": "1.10186",
        "c": "1.10188"
      }
    }
  ]
}
